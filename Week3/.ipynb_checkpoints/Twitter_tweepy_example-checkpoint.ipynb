# %% [markdown]
# tweepy
#
# Official documentation: https://docs.tweepy.org/en/stable/
#
# Ref: https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9

# %%
import tweepy
import datetime
import pandas as pd
import json
import requests

# %%
# Paste in your own bearer token
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAAOlFYQEAAAAA564Nq2buxWcuVMiwrxqNcrlFwfI%3DO6AkqhR3vBDKQnVJWaL04FQp0yaMBbz7GCeCLWwdUhba1NU6le'

client = tweepy.Client(bearer_token=BEARER_TOKEN, return_type=requests.Response)

# %%
'''
Searching for Tweets from the last 7 days

We can use the search_recent_tweets function available in Tweepy.
You will have to pass it a search query to specify the data that you are looking for.

Below, we will search for for Tweets from the last days from the 
Twitter handle realDonaldTrump and we are excluding retweets using -is:retweet.

By default, a request returns 10 Tweets.
If you want more than 10 Tweets per request, you can specify that using the max_results parameter.
The maximum Tweets per request is 100.
'''
# Replace with your own search query
handle = 'KimKardashian'
query = 'from:' + handle + ' -is:retweet'

tweets1 = client.search_recent_tweets(
            query=query,
            tweet_fields=['context_annotations', 'created_at'],
            max_results=100)

# %%
'''
Convert to pandas Dataframe
'''

# Save data as dictionary
tweets_dict1 = tweets1.json()

# Extract "data" value from dictionary
tweets_data1 = tweets_dict1['data'] 

# Transform to pandas Dataframe
df1 = pd.json_normalize(tweets_data1)

df1
# Out:
#                                   context_annotations                   id  \
# 0   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491475885563650049
# 1   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491459749874860035
# 2   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491442609747001344
# 3   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491400859879895041
# 4   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491400820793180162
# 5   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491400792607117313
# 6   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491400756913590272
# 7   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491400734495363074
# 8   [{'domain': {'id': '10', 'name': 'Person', 'de...  1491400676421021701
# 9   [{'domain': {'id': '10', 'name': 'Person', 'de...  1490824844698533889
# 10  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...  1489401564284346369
#
#                                                  text  \
# 0             Styled by North https://t.co/DCv1HWbWUK
# 1   Just dropped @SKIMS Shimmer! Available now at ...
# 2          SKIMS in Vogue!!!! https://t.co/4JdsrZRJvX
# 3                    VOGUE US https://t.co/IXDq7UZhzB
# 4                    VOGUE US https://t.co/W307eTZvB8
# 5                    VOGUE US https://t.co/PxwHUz6MRJ
# 6                    VOGUE US https://t.co/RdROe7aQfl
# 7                    VOGUE US https://t.co/YxCvJVTJLK
# 8   VOGUE US \n\nPhotographer: @CarlijnJacobs\nFas...
# 9   far away close together @lala ♾ https://t.co/G...
# 10  Follow @kardashianshulu for all of our content...
#
#                   created_at
# 0   2022-02-09T18:15:36.000Z
# 1   2022-02-09T17:11:29.000Z
# 2   2022-02-09T16:03:22.000Z
# 3   2022-02-09T13:17:28.000Z
# 4   2022-02-09T13:17:19.000Z
# 5   2022-02-09T13:17:12.000Z
# 6   2022-02-09T13:17:03.000Z
# 7   2022-02-09T13:16:58.000Z
# 8   2022-02-09T13:16:44.000Z
# 9   2022-02-07T23:08:35.000Z
# 10  2022-02-04T00:52:59.000Z

# %%
'''
If you want to get Tweets for a specific time-period, you can specify the time-period
using the start_time and end_time parameters, as shown in the example below:
'''

# Replace with time period of your choice
start_time = '2022-02-03T00:00:00Z'

# Replace with time period of your choice
end_time = '2022-02-05T00:00:00Z'


# Replace with your own search query
handle = 'elonmusk'
query = 'from:' + handle + ' -is:retweet'

tweets2 = client.search_recent_tweets(
            query=query,
            tweet_fields=['context_annotations', 'created_at'],
            start_time=start_time,
            end_time=end_time,
            max_results=100)

'''
Convert to pandas Dataframe
'''
df2 = pd.json_normalize(tweets2)

tweets2.json()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# Input In [9], in <module>
#      14 handle = 'elonmusk'
#      15 query = 'from:' + handle + ' -is:retweet'
# ---> 17 tweets2 = client.search_recent_tweets(
#      18             query=query,
#      19             tweet_fields=['context_annotations', 'created_at'],
#      20             start_time=start_time,
#      21             end_time=end_time,
#      22             max_results=100)
#      24 '''
#      25 Convert to pandas Dataframe
#      26 '''
#      27 df2 = pd.json_normalize(tweets2)
#
# File c:\users\cheong kenn ee\onedrive - singapore management university\5 uni stuff\y3s2\sa\venv\lib\site-packages\tweepy\client.py:791, in Client.search_recent_tweets(self, query, user_auth, **params)
#     710 """search_recent_tweets( \
#     711     query, *, user_auth=False, end_time, expansions, max_results, \
#     712     media_fields, next_token, place_fields, poll_fields, since_id, \
#    (...)
#     788 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#     789 """
#     790 params["query"] = query
# --> 791 return self._make_request(
#     792     "GET", "/2/tweets/search/recent", params=params,
#     793     endpoint_parameters=(
#     794         "end_time", "expansions", "max_results", "media.fields",
#     795         "next_token", "place.fields", "poll.fields", "query",
#     796         "since_id", "start_time", "tweet.fields", "until_id",
#     797         "user.fields"
#     798     ), data_type=Tweet, user_auth=user_auth
#     799 )
#
# File c:\users\cheong kenn ee\onedrive - singapore management university\5 uni stuff\y3s2\sa\venv\lib\site-packages\tweepy\client.py:166, in Client._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     163     if param_name not in endpoint_parameters:
#     164         log.warn(f"Unexpected parameter: {param_name}")
# --> 166 response = self.request(method, route, params=request_params,
#     167                         json=json, user_auth=user_auth)
#     169 if self.return_type is requests.Response:
#     170     return response
#
# File c:\users\cheong kenn ee\onedrive - singapore management university\5 uni stuff\y3s2\sa\venv\lib\site-packages\tweepy\client.py:120, in Client.request(self, method, route, params, json, user_auth)
#     112 log.debug(
#     113     "Received API response: "
#     114     f"{response.status_code} {response.reason}\n"
#     115     f"Headers: {response.headers}\n"
#     116     f"Content: {response.content}"
#     117 )
#     119 if response.status_code == 400:
# --> 120     raise BadRequest(response)
#     121 if response.status_code == 401:
#     122     raise Unauthorized(response)
#
# BadRequest: 400 Bad Request
# Invalid 'start_time':'2022-02-03T00:00Z'. 'start_time' must be on or after 2022-02-03T07:46Z

# %%
'''
Writing Tweets to a text file

This example shows how you can write the Tweet IDs for each Tweet obtained 
for a search result, to a text file.

Make sure to replace the file_name with the a name of your chosing.

If you wish to write other fields to the text file, make sure to adjust the script below accordingly.
'''

file_name = 'tweets.txt'

df2.to_csv(file_name, index=False, encoding='utf-8')

# If you want a different delimiter, say, tab or '\t'
# You can do:
#    df2.to_csv(file_name, index=False, encoding='utf-8', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <module>
#       1 '''
#       2 Writing Tweets to a text file
#       3
#    (...)
#       9 If you wish to write other fields to the text file, make sure to adjust the script below accordingly.
#      10 '''
#      12 file_name = 'tweets.txt'
# ---> 14 df2.to_csv(file_name, index=False, encoding='utf-8')
#
# NameError: name 'df2' is not defined
