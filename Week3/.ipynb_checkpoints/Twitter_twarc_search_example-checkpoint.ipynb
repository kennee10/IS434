# %% [markdown]
# In this lab, we will use 'twarc' Python package to interact with Twitter API v2.
#
# We will use Search Tweets --> Recent search (endpoint)
#
# This API endpoint:
# - (By default) Retrieves 10 tweets in the recent 7 days
# - (By setting max_results to 100) Can retrieve up to 100 tweets per API request
#
# Ref: https://twarc-project.readthedocs.io/en/latest/api/client2/#twarc.client2.Twarc2.search_recent
#
# Ref: https://www.youtube.com/watch?v=guHH51GDDI0
#
# Ref: https://catriscode.com/2021/05/01/tweets-cleaning-with-python/

# %%
import plotly.graph_objects as go
from twarc import Twarc2

# %%
# Paste in your own bearer token below
client = Twarc2(
    bearer_token = 'AAAAAAAAAAAAAAAAAAAAAOlFYQEAAAAA564Nq2buxWcuVMiwrxqNcrlFwfI%3DO6AkqhR3vBDKQnVJWaL04FQp0yaMBbz7GCeCLWwdUhba1NU6le'
)

# %%
query = 'covid lang=en'

# %%
results = client.search_recent(
    query=query,
    max_results=100,
    tweet_fields="author_id,context_annotations"
)

# %%
for page in results:
    print("======================")
    print(page)
    data = page['data']
# Out:
# ======================
# {'data': [{'id': '1491547939625385988', 'author_id': '934230006611324929', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': "RT @FrankGrimes_Jr: @MichaelPSenger It was nice of them to say covid couldn't be spread person to person. And then blocked investigators. T…", 'referenced_tweets': [{'type': 'retweeted', 'id': '1491545704845746180'}], 'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'FrankGrimes_Jr', 'id': '900819727'}, {'start': 20, 'end': 35, 'username': 'MichaelPSenger', 'id': '1679362640'}]}}, {'id': '1491547897925615624', 'author_id': '1099867418367791104', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': "RT @FrankGrimes_Jr: @MichaelPSenger It was nice of them to say covid couldn't be spread person to person. And then blocked investigators. T…", 'referenced_tweets': [{'type': 'retweeted', 'id': '1491545704845746180'}], 'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'FrankGrimes_Jr', 'id': '900819727'}, {'start': 20, 'end': 35, 'username': 'MichaelPSenger', 'id': '1679362640'}]}}, {'id': '1491545704845746180', 'in_reply_to_user_id': '1679362640', 'author_id': '900819727', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': "@MichaelPSenger It was nice of them to say covid couldn't be spread person to person. And then blocked investigators. Thanks for the help!\n\nhttps://t.co/grEy0LKHMn", 'referenced_tweets': [{'type': 'quoted', 'id': '1217043229427761152'}, {'type': 'replied_to', 'id': '1491496598760611840'}], 'entities': {'mentions': [{'start': 0, 'end': 15, 'username': 'MichaelPSenger', 'id': '1679362640'}]}}, {'id': '1491506434688831490', 'in_reply_to_user_id': '51754021', 'author_id': '1189212168', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': '@rolandbouman @catalan_rob Het COVID-19 is nog niet geïsoleerd er zijn ruim 400 COVID variaties die bestaan al lang en enkele zijn geïsoleerd maar dit door de mens gecreëerde virus niet', 'referenced_tweets': [{'type': 'replied_to', 'id': '1491505823599710213'}], 'entities': {'mentions': [{'start': 0, 'end': 13, 'username': 'rolandbouman', 'id': '51754021'}, {'start': 14, 'end': 26, 'username': 'catalan_rob', 'id': '1421978222187646977'}]}}, {'id': '1491494703900069894', 'author_id': '2424007068', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @LiseCandlestick: @KenWinGrey @jenkew FYI, being seated "away from others" does very little to reduce your exposure to Covid/Omicron. Co…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1491471524972408835'}], 'entities': {'mentions': [{'start': 3, 'end': 19, 'username': 'LiseCandlestick', 'id': '1322644460824530944'}, {'start': 21, 'end': 32, 'username': 'KenWinGrey', 'id': '215426830'}, {'start': 33, 'end': 40, 'username': 'jenkew', 'id': '16653010'}]}}, {'id': '1491471524972408835', 'in_reply_to_user_id': '215426830', 'author_id': '1322644460824530944', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': '@KenWinGrey @jenkew FYI, being seated "away from others" does very little to reduce your exposure to Covid/Omicron. Covid is airborne and cumulative, like cigarette smoke.  https: ...
# ======================
# {'data': [{'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 11, 'username': 'NaimeDr', 'id': '1180109754527551488'}]}, 'author_id': '760224068205416448', 'text': 'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1489628294354030600'}], 'id': '1489690503717265408'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 12, 'username': 'nukaboko', 'id': '109279512'}]}, 'author_id': '154413370', 'text': 'RT @nukaboko: 日々のリリースは\nhttps://t.co/pHWY1kZHBm\nここで見ればよさそう\nしかしデータは画像である\n#北京五輪2022 コロナ情報', 'referenced_tweets': [{'type': 'retweeted', 'id': '1489654855132069891'}], 'id': '1489683220946112512'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]}, 'author_id': '17229748', 'text': 'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 February 4 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1489610454238437382'}], 'id': '1489662059272937481'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'cint', 'id': '17229748'}]}, 'author_id': '1197472679672070146', 'text': 'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 February 4 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1489610454238437382'}], 'id': '1489661308362498055'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 11, 'username': 'NaimeDr', 'id': '1180109754527551488'}]}, 'author_id': '54588657', 'text': 'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1489628294354030600'}], 'id': '1489660108476981251'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'in_reply_to_user_id': '109279512', 'author_id': '109279512', 'text': '日々のリリースは\nhttps://t.co/pHWY1kZHBm\nここで見ればよさそう\nしかしデータは画像である\n#北京五輪2022 コロナ情報', 'referenced_tweets': [{'type': 'replied_to', 'id': '1489651089825677314'}], 'id': '1489654855132069891'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'entities': {'mentions': [{'start': 3, 'end': 11, 'username': 'NaimeDr', 'id': '1180109754527551488'}]}, 'author_id': '1002704074523979777', 'text': 'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…', 'referenced_tweets': [{'type': 'retweeted', 'id': '1489628294354030600'}], 'id': '1489654086135951361'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'descr ...

# %%
len(data)
# Out:
# 55

# %%
# Convert JSON into Pandas data frame

import pandas as pd

df = pd.json_normalize(data)

df
# Out:
#                                   context_annotations            author_id  \
# 0   [{'domain': {'id': '123', 'name': 'Ongoing New...   760224068205416448
# 1   [{'domain': {'id': '123', 'name': 'Ongoing New...            154413370
# 2   [{'domain': {'id': '123', 'name': 'Ongoing New...             17229748
# 3   [{'domain': {'id': '123', 'name': 'Ongoing New...  1197472679672070146
# 4   [{'domain': {'id': '123', 'name': 'Ongoing New...             54588657
# 5   [{'domain': {'id': '123', 'name': 'Ongoing New...            109279512
# 6   [{'domain': {'id': '123', 'name': 'Ongoing New...  1002704074523979777
# 7   [{'domain': {'id': '123', 'name': 'Ongoing New...             48231963
# 8   [{'domain': {'id': '123', 'name': 'Ongoing New...  1168707968071798784
# 9   [{'domain': {'id': '123', 'name': 'Ongoing New...   968608533003501568
# 10  [{'domain': {'id': '123', 'name': 'Ongoing New...            628312859
# 11  [{'domain': {'id': '123', 'name': 'Ongoing New...   817359518459985920
# 12  [{'domain': {'id': '123', 'name': 'Ongoing New...  1415340176050728961
# 13  [{'domain': {'id': '123', 'name': 'Ongoing New...             29211398
# 14  [{'domain': {'id': '123', 'name': 'Ongoing New...  1018272885813731329
# 15  [{'domain': {'id': '123', 'name': 'Ongoing New...             17778308
# 16  [{'domain': {'id': '123', 'name': 'Ongoing New...             16574781
# 17  [{'domain': {'id': '123', 'name': 'Ongoing New...            152692466
# 18  [{'domain': {'id': '123', 'name': 'Ongoing New...             20877834
# 19  [{'domain': {'id': '123', 'name': 'Ongoing New...  1244088151569838083
# 20  [{'domain': {'id': '123', 'name': 'Ongoing New...  1197613055917604864
# 21  [{'domain': {'id': '123', 'name': 'Ongoing New...             76988994
# 22  [{'domain': {'id': '123', 'name': 'Ongoing New...             46932006
# 23  [{'domain': {'id': '123', 'name': 'Ongoing New...  1107142942345609216
# 24  [{'domain': {'id': '123', 'name': 'Ongoing New...             90441288
# 25  [{'domain': {'id': '123', 'name': 'Ongoing New...  1180109754527551488
# 26  [{'domain': {'id': '123', 'name': 'Ongoing New...            123490093
# 27  [{'domain': {'id': '123', 'name': 'Ongoing New...             17229748
# 28  [{'domain': {'id': '123', 'name': 'Ongoing New...   983470939336822784
# 29  [{'domain': {'id': '123', 'name': 'Ongoing New...  1300678265456201734
# 30  [{'domain': {'id': '123', 'name': 'Ongoing New...            219259144
# 31                                                NaN  1092055153719488512
# 32  [{'domain': {'id': '123', 'name': 'Ongoing New...             17229748
# 33                                                NaN  1359440105530814470
# 34  [{'domain': {'id': '123', 'name': 'Ongoing New...   824684311827738624
# 35                                                NaN  1475180822701486084
# 36  [{'domain': {'id': '66', 'name': 'Interests an...           1707730988
# 37  [{'domain': {'id': '45', 'name': 'Brand Vertic...             16938726
# 38                                                NaN           1086982639
# 39  [{'domain': {'id': '123', 'name': 'Ongoing New...            298689306
# 40  [{'domain': {'id': '123', 'name': 'Ongoing New...   997431740892401665
# 41                                                NaN            136928086
# 42  [{'domain': {'id': '123', 'name': 'Ongoing New...           1489895438
# 43                                                NaN           2798453983
# 44  [{'domain': {'id': '123', 'name': 'Ongoing New...   827182422303334400
# 45  [{'domain': {'id': '123', 'name': 'Ongoing New...            628312859
# 46  [{'domain': {'id': '123', 'name': 'Ongoing New...             17229748
# 47  [{'domain': {'id': '123', 'name': 'Ongoing New...  1467544925902356481
# 48  [{'domain': {'id': '123', 'name': 'Ongoing New...  1327968672279793664
# 49  [{'domain': {'id': '123', 'name': 'Ongoing New...   893075603280343040
# 50  [{'domain': {'id': '123', 'name': 'Ongoing New...  1071396742623571968
# 51  [{'domain': {'id': '123', 'name': 'Ongoing New...  1045124724005597184
# 52  [{'domain': {'id': '123', 'name': 'Ongoing New...            473950534
# 53  [{'domain': {'id': '123', 'name': 'Ongoing New...             17839398
# 54  [{'domain': {'id': '88', 'name': 'Political Bo...            298689306
#
#                                                  text  \
# 0   RT @NaimeDr: Estudos apontam que Gestantes vac...
# 1   RT @nukaboko: 日々のリリースは\nhttps://t.co/pHWY1kZHB...
# 2   RT @cint: https://t.co/c1SEviKkAw\n#Dutch #cov...
# 3   RT @cint: https://t.co/c1SEviKkAw\n#Dutch #cov...
# 4   RT @NaimeDr: Estudos apontam que Gestantes vac...
# 5   日々のリリースは\nhttps://t.co/pHWY1kZHBm\nここで見ればよさそう\...
# 6   RT @NaimeDr: Estudos apontam que Gestantes vac...
# 7   RT @NaimeDr: Estudos apontam que Gestantes vac...
# 8   RT @NaimeDr: Estudos apontam que Gestantes vac...
# 9   RT @NaimeDr: Estudos apontam que Gestantes vac...
# 10  RT @cint: https://t.co/c1SEviKkAw\n#Dutch #cov...
# 11  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 12  Use of indomethacin in COVID-19 patients - exp...
# 13  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 14  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 15  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 16  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 17  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 18  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 19  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 20  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 21  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 22  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 23  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 24  RT @NaimeDr: Estudos apontam que Gestantes vac...
# 25  Estudos apontam que Gestantes vacinadas com Co...
# 26  RT @KenRoth: The Chinese government has made e...
# 27  https://t.co/c1SEviKkAw\n#Dutch #covid19 Febru...
# 28  RT @BRFAA_IIBEAA: ‼️🔬Research Highlights :  \n...
# 29  ‼️🔬Research Highlights :  \nPulmonary infectio...
# 30  The #NFP is out today.\n\nHow many #jobs were ...
# 31                            https://t.co/MWHmBjdcUg
# 32  RT @cint: https://t.co/c1SEvisJbW\n#Dutch #cov...
# 33  @SougPaul Not entirely fair: https://t.co/9hVk...
# 34  @Jonatha16813684 @AnarchoDave @kgnors79 @DTepl...
# 35  ➡️https://t.co/JpF8znIeQa\n➡️https://t.co/R493...
# 36  RT @MarthaENewton: Remote work has accelerated...
# 37  @elonmusk Hey "genius", how is the move to a s...
# 38    @Judithole @eduardoinda https://t.co/5V92bFWrht
# 39  Ministry of Health of Kuwait reports 5,990 peo...
# 40  @michaelgrandner Covered some of these in our ...
# 41          @edaonay @ulcisko https://t.co/WyQ1Gvrohz
# 42  Report on the Rapid Assessment Survey: The Res...
# 43          [Media Mentions]  https://t.co/lwyMGzKUNo
# 44  RT @KenRoth: The Chinese government has made e...
# 45  RT @cint: https://t.co/c1SEvisJbW\n#Dutch #cov...
# 46  https://t.co/c1SEvisJbW\n#Dutch #covid19 Febru...
# 47  RT @ContainmentNu: @BrianMaudling @BNODesk And...
# 48  RT @KenRoth: The Chinese government has made e...
# 49  RT @KenRoth: The Chinese government has made e...
# 50  RT @KenRoth: The Chinese government has made e...
# 51  RT @KenRoth: The Chinese government has made e...
# 52  RT @KenRoth: The Chinese government has made e...
# 53  The Chinese government has made enormous effor...
# 54  The Saudi Ministry of Health announced the reg...
#
#                                     referenced_tweets                   id  \
# 0   [{'type': 'retweeted', 'id': '1489628294354030...  1489690503717265408
# 1   [{'type': 'retweeted', 'id': '1489654855132069...  1489683220946112512
# 2   [{'type': 'retweeted', 'id': '1489610454238437...  1489662059272937481
# 3   [{'type': 'retweeted', 'id': '1489610454238437...  1489661308362498055
# 4   [{'type': 'retweeted', 'id': '1489628294354030...  1489660108476981251
# 5   [{'type': 'replied_to', 'id': '148965108982567...  1489654855132069891
# 6   [{'type': 'retweeted', 'id': '1489628294354030...  1489654086135951361
# 7   [{'type': 'retweeted', 'id': '1489628294354030...  1489653260537450498
# 8   [{'type': 'retweeted', 'id': '1489628294354030...  1489653097815281667
# 9   [{'type': 'retweeted', 'id': '1489628294354030...  1489647990990118913
# 10  [{'type': 'retweeted', 'id': '1489610454238437...  1489647608339517440
# 11  [{'type': 'retweeted', 'id': '1489628294354030...  1489641951641092100
# 12                                                NaN  1489641349561393158
# 13  [{'type': 'retweeted', 'id': '1489628294354030...  1489640105916653569
# 14  [{'type': 'retweeted', 'id': '1489628294354030...  1489639030849519621
# 15  [{'type': 'retweeted', 'id': '1489628294354030...  1489638263698731008
# 16  [{'type': 'retweeted', 'id': '1489628294354030...  1489637825981124616
# 17  [{'type': 'retweeted', 'id': '1489628294354030...  1489636360139022338
# 18  [{'type': 'retweeted', 'id': '1489628294354030...  1489636344452296709
# 19  [{'type': 'retweeted', 'id': '1489628294354030...  1489636294888153090
# 20  [{'type': 'retweeted', 'id': '1489628294354030...  1489635266834878470
# 21  [{'type': 'retweeted', 'id': '1489628294354030...  1489635082730184705
# 22  [{'type': 'retweeted', 'id': '1489628294354030...  1489634922381942789
# 23  [{'type': 'retweeted', 'id': '1489628294354030...  1489631057892843523
# 24  [{'type': 'retweeted', 'id': '1489628294354030...  1489630798873604102
# 25                                                NaN  1489628294354030600
# 26  [{'type': 'retweeted', 'id': '1489202202224873...  1489614292408168448
# 27                                                NaN  1489610454238437382
# 28  [{'type': 'retweeted', 'id': '1489570715787567...  1489571919208894468
# 29                                                NaN  1489570715787567108
# 30                                                NaN  1489539827703816196
# 31                                                NaN  1489531776725037057
# 32  [{'type': 'retweeted', 'id': '1489246564941926...  1489526041844584451
# 33  [{'type': 'replied_to', 'id': '148948723751571...  1489491392753639426
# 34  [{'type': 'quoted', 'id': '1337912764879269888...  1489418264778194947
# 35  [{'type': 'replied_to', 'id': '148132254202356...  1489382660317265920
# 36  [{'type': 'retweeted', 'id': '1488859791900520...  1489381463367856134
# 37  [{'type': 'quoted', 'id': '1240754657263144960...  1489335047828099073
# 38  [{'type': 'replied_to', 'id': '148898886648907...  1489311207622385664
# 39                                                NaN  1489281984727855114
# 40  [{'type': 'replied_to', 'id': '148865010473089...  1489271536687226880
# 41  [{'type': 'replied_to', 'id': '148927114565643...  1489271177163980805
# 42                                                NaN  1489269864544235520
# 43                                                NaN  1489257829923835915
# 44  [{'type': 'retweeted', 'id': '1489202202224873...  1489255108797878276
# 45  [{'type': 'retweeted', 'id': '1489246564941926...  1489246663298347017
# 46                                                NaN  1489246564941926401
# 47  [{'type': 'retweeted', 'id': '1488998766183129...  1489224435055972355
# 48  [{'type': 'retweeted', 'id': '1489202202224873...  1489216485554003968
# 49  [{'type': 'retweeted', 'id': '1489202202224873...  1489203096412729350
# 50  [{'type': 'retweeted', 'id': '1489202202224873...  1489202678651670531
# 51  [{'type': 'retweeted', 'id': '1489202202224873...  1489202486141685763
# 52  [{'type': 'retweeted', 'id': '1489202202224873...  1489202326179041280
# 53                                                NaN  1489202202224873482
# 54                                                NaN  1489175728918835203
#
#                                     entities.mentions  in_reply_to_user_id  \
# 0   [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 1   [{'start': 3, 'end': 12, 'username': 'nukaboko...                  NaN
# 2   [{'start': 3, 'end': 8, 'username': 'cint', 'i...                  NaN
# 3   [{'start': 3, 'end': 8, 'username': 'cint', 'i...                  NaN
# 4   [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 5                                                 NaN            109279512
# 6   [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 7   [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 8   [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 9   [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 10  [{'start': 3, 'end': 8, 'username': 'cint', 'i...                  NaN
# 11  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 12                                                NaN                  NaN
# 13  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 14  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 15  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 16  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 17  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 18  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 19  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 20  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 21  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 22  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 23  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 24  [{'start': 3, 'end': 11, 'username': 'NaimeDr'...                  NaN
# 25                                                NaN                  NaN
# 26  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 27                                                NaN                  NaN
# 28  [{'start': 3, 'end': 16, 'username': 'BRFAA_II...                  NaN
# 29                                                NaN                  NaN
# 30                                                NaN                  NaN
# 31                                                NaN                  NaN
# 32  [{'start': 3, 'end': 8, 'username': 'cint', 'i...                  NaN
# 33  [{'start': 0, 'end': 9, 'username': 'SougPaul'...            192476931
# 34  [{'start': 0, 'end': 16, 'username': 'Jonatha1...  1483128938796924934
# 35                                                NaN  1475180822701486084
# 36  [{'start': 3, 'end': 17, 'username': 'MarthaEN...                  NaN
# 37  [{'start': 0, 'end': 9, 'username': 'elonmusk'...             44196397
# 38  [{'start': 0, 'end': 10, 'username': 'Judithol...            380596194
# 39                                                NaN                  NaN
# 40  [{'start': 0, 'end': 16, 'username': 'michaelg...             12234492
# 41  [{'start': 0, 'end': 8, 'username': 'edaonay',...            136928086
# 42  [{'start': 145, 'end': 149, 'username': 'ilo',...                  NaN
# 43                                                NaN                  NaN
# 44  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 45  [{'start': 3, 'end': 8, 'username': 'cint', 'i...                  NaN
# 46                                                NaN                  NaN
# 47  [{'start': 3, 'end': 17, 'username': 'Containm...                  NaN
# 48  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 49  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 50  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 51  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 52  [{'start': 3, 'end': 11, 'username': 'KenRoth'...                  NaN
# 53                                                NaN                  NaN
# 54                                                NaN                  NaN
#
#                             attachments.media_keys
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                         [3_1489628274011615236]
# 26                                             NaN
# 27                         [3_1489610016223027201]
# 28                                             NaN
# 29                         [3_1489570711274508295]
# 30                         [3_1489539826235883520]
# 31                                             NaN
# 32                                             NaN
# 33                                             NaN
# 34                                             NaN
# 35                         [3_1489382478825545728]
# 36                                             NaN
# 37                                             NaN
# 38                                             NaN
# 39                         [3_1489281983444312064]
# 40                                             NaN
# 41                                             NaN
# 42  [3_1489269848605708289, 3_1489269848584634368]
# 43                                             NaN
# 44                                             NaN
# 45                                             NaN
# 46                         [3_1489245910504673282]
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
# 50                                             NaN
# 51                                             NaN
# 52                                             NaN
# 53                                             NaN
# 54                         [3_1489175727878676492]

# %%
# Let's retrieve just the text from each tweet
# Store each tweet text as a List item

tweet_text_list = df['text'].tolist()

tweet_text_list
# Out:
# ['RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @nukaboko: 日々のリリースは\nhttps://t.co/pHWY1kZHBm\nここで見ればよさそう\nしかしデータは画像である\n#北京五輪2022 コロナ情報',
#  'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 February 4 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…',
#  'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 February 4 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  '日々のリリースは\nhttps://t.co/pHWY1kZHBm\nここで見ればよさそう\nしかしデータは画像である\n#北京五輪2022 コロナ情報',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @cint: https://t.co/c1SEviKkAw\n#Dutch #covid19 February 4 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'Use of indomethacin in COVID-19 patients - experience from two medical centres https://t.co/npXTOyhzvU',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'RT @NaimeDr: Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos…',
#  'Estudos apontam que Gestantes vacinadas com Coronavac protegem diretamente seus recém-nascidos pela transmissão de anticorpos neutralizantes \n\nLeia a matéria em https://t.co/xhtV5UtkTa\n\nLink para o estudo em https://t.co/krfQw1U2lz\n\n#infectologia #coronavac #vacina #gestante https://t.co/gdOQduLFnX',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'https://t.co/c1SEviKkAw\n#Dutch #covid19 February 4 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM:  +68916 (4.757.035)\nIn #Hospital NICE from 12:00 AM: +28 (81.259)\n#Deaths: +3 (21.313)\n\n#Netherlands #corona #BoosterJab #StaySafe #Omicron #BA2 #GGD https://t.co/JsG5VE837o',
#  'RT @BRFAA_IIBEAA: ‼️🔬Research Highlights :  \nPulmonary infection by SARS-CoV-2 induces senescence accompanied by an inflammatory phenotype…',
#  '‼️🔬Research Highlights :  \nPulmonary infection by SARS-CoV-2 induces senescence accompanied by an inflammatory phenotype in severe COVID-19: possible implications for viral mutagenesis"\n🔗https://t.co/LxVNv9QxC4 https://t.co/AtUSIjDSVz',
#  'The #NFP is out today.\n\nHow many #jobs were added during #COVID-19’s worst spikes?\n\nPrevious: 199K\nForecast: 238K\n\nTrade the NFP. https://t.co/Cad7xlmr7S https://t.co/yR5dLMyjdK',
#  'https://t.co/MWHmBjdcUg',
#  'RT @cint: https://t.co/c1SEvisJbW\n#Dutch #covid19 February 3 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…',
#  '@SougPaul Not entirely fair: https://t.co/9hVkfzCwPt\n\nAlso, don’t forget the monthly fines on the unvaxxed aged: https://t.co/DK3B4tKmnw',
#  '@Jonatha16813684 @AnarchoDave @kgnors79 @DTeplitzer But healthy people get sick and die from covid too. Its not just being fat and old that makes covid lethal. Its also pretty bad health-wise to get covid. Better to get vaxxed and try any avoid getting sick\nhttps://t.co/5Uh1OQL0je\nhttps://t.co/NHNrWpyXjL\nhttps://t.co/UYRDuNEsOh',
#  '➡️https://t.co/JpF8znIeQa\n➡️https://t.co/R493R36Co8 https://t.co/ME3Ksq6ryk',
#  'RT @MarthaENewton: Remote work has accelerated during the COVID-19. \n\nNew @ILO &amp; @WHO report on benefits &amp; concerns, as well as the roles t…',
#  '@elonmusk Hey "genius", how is the move to a state with power grid issues to build your electric cars going? I bet almost as well as your COVID predictions https://t.co/S0nhNdoAKH',
#  '@Judithole @eduardoinda https://t.co/5V92bFWrht',
#  'Ministry of Health of Kuwait reports 5,990 people tested positive for coronavirus (COVID-19), two deaths, in the past 24 hours. #QNA\nhttps://t.co/3VGKPwtlaJ https://t.co/S6Y4ba7rM5',
#  '@michaelgrandner Covered some of these in our Sleep, Health and Society textbooks but agree need more on sleep and cancer, concussion, mental health, COVID and long COVID etc.\n\nhttps://t.co/UuZdKOS7bM',
#  '@edaonay @ulcisko https://t.co/WyQ1Gvrohz',
#  'Report on the Rapid Assessment Survey: The Response of Labour Dispute Resolution Mechanisms to the COVID-19 Pandemic https://t.co/JjPqdSo6ht via @ilo https://t.co/MAdnLpoxXZ',
#  '[Media Mentions]  https://t.co/lwyMGzKUNo',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'RT @cint: https://t.co/c1SEvisJbW\n#Dutch #covid19 February 3 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM…',
#  'https://t.co/c1SEvisJbW\n#Dutch #covid19 February 3 #visualization on #independent #interactive #dashboard.\n\nPositive #cases #RIVM:  +82871 (4.688.119)\nIn #Hospital NICE from 12:00 AM: +14 (80.968)\n#Deaths: +7 (21.310)\n\n#Netherlands #corona #BoosterJab #StaySafe #Omicron #BA2 https://t.co/BLoF1ZVEXM',
#  'RT @ContainmentNu: @BrianMaudling @BNODesk And 65 Covid scandals.\nhttps://t.co/2QwdkXDOwZ',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'RT @KenRoth: The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public…',
#  'The Chinese government has made enormous efforts to prevent Olympic participants from spreading Covid-19 to the Chinese public while making only half-hearted efforts to prevent the participants from spreading it to each other. https://t.co/dgGh7PDUlP',
#  'The Saudi Ministry of Health announced the registration of 3,852 new infections with Coronavirus (COVID-19) during the past 24 hours, bringing the total number of infections recorded in the country to 699,069. Four deaths were recorded. #QNA https://t.co/wWKKepAEbe https://t.co/nBa3UlP1fH']

# %%
'''
1) Lowercasing all the letters

This step is important to make sure that all your letters are in uniform.

temp = tweet.lower()
temp
'''
# Out:
# '\n1) Lowercasing all the letters\n\nThis step is important to make sure that all your letters are in uniform.\n\ntemp = tweet.lower()\ntemp\n'

# %%
'''
2) Removing hashtags and mentions

Hashtags and mentions are common in tweets.
There are cases where you want to remove them so you only get the 
clean content of a tweet without all these elements.

You can remove these hashtags and mentions using regex.

import re

temp = re.sub("@[A-Za-z0-9_]+","", temp)
temp = re.sub("#[A-Za-z0-9_]+","", temp)
temp
'''
# Out:
# '\n2) Removing hashtags and mentions\n\nHashtags and mentions are common in tweets.\nThere are cases where you want to remove them so you only get the \nclean content of a tweet without all these elements.\n\nYou can remove these hashtags and mentions using regex.\n\nimport re\n\ntemp = re.sub("@[A-Za-z0-9_]+","", temp)\ntemp = re.sub("#[A-Za-z0-9_]+","", temp)\ntemp\n'

# %%
'''
3) Removing links

Links are usually not necessary for text processing, so it’s
better to remove them from your text.

temp = re.sub(r"http\S+", "", temp)
temp = re.sub(r"www.\S+", "", temp)
temp
'''
# Out:
# '\n3) Removing links\n\nLinks are usually not necessary for text processing, so it’s\nbetter to remove them from your text.\n\ntemp = re.sub(r"http\\S+", "", temp)\ntemp = re.sub(r"www.\\S+", "", temp)\ntemp\n'

# %%
'''
4) Removing punctuations

Depending on your needs, you may not need punctuations such as
period, comma, exclamation mark, question mark, etc.

temp = re.sub('[()!?]', ' ', temp)
temp = re.sub('\[.*?\]',' ', temp)
temp
'''
# Out:
# "\n4) Removing punctuations\n\nDepending on your needs, you may not need punctuations such as\nperiod, comma, exclamation mark, question mark, etc.\n\ntemp = re.sub('[()!?]', ' ', temp)\ntemp = re.sub('\\[.*?\\]',' ', temp)\ntemp\n"

# %%
'''
5) Filtering non-alphanumeric characters

The previous step may have removed the punctuations, including all the
non-alphanumeric characters, but just to be sure, we can remove all letters
except the alphabets (a-z) and numbers (0-9). The sign ^ below means except.

temp = re.sub("[^a-z0-9]"," ", temp)
temp
'''
# Out:
# '\n5) Filtering non-alphanumeric characters\n\nThe previous step may have removed the punctuations, including all the\nnon-alphanumeric characters, but just to be sure, we can remove all letters\nexcept the alphabets (a-z) and numbers (0-9). The sign ^ below means except.\n\ntemp = re.sub("[^a-z0-9]"," ", temp)\ntemp\n'

# %%
'''
6) Tokenization

In tokenization, you basically tokenize your text into tokens.

And what is a token? In this case, you split your text into smaller components,
for example a paragraph into a list of sentences, or a sentence into a list of words.

Library such as nltk provides functions such as word_tokenize() or sent_tokenize()
to help you with this.

However, if you just want a simple tokenizing step where you split your text 
into words into a list, then you can do it as simple as the following code.

The result will give you a list of words from your text.

temp = temp.split()
temp
'''
# Out:
# '\n6) Tokenization\n\nIn tokenization, you basically tokenize your text into tokens.\n\nAnd what is a token? In this case, you split your text into smaller components,\nfor example a paragraph into a list of sentences, or a sentence into a list of words.\n\nLibrary such as nltk provides functions such as word_tokenize() or sent_tokenize()\nto help you with this.\n\nHowever, if you just want a simple tokenizing step where you split your text \ninto words into a list, then you can do it as simple as the following code.\n\nThe result will give you a list of words from your text.\n\ntemp = temp.split()\ntemp\n'

# %%
'''
7) Stop words removal

Stop words are words that are considered unimportant to the meaning of a text.
These words may seem important to us, humans, but to machine these words may be
considered nuisance to the processing steps.

It’s also important to keep in mind that stop words are largely language-dependent.
In English, you have stop words such as for, to, and, or, in, out, etc.

Here I first defined a list of stop words in English.
Then, I match each token with each stop word.

If a token isn’t found in the list of stop words, the token gets saved,
otherwise it’s not saved. In the end, you join all the words into one text again.


stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
 
temp = [w for w in temp if not w in stopwords]
temp = " ".join(word for word in temp)
'''
# Out:
# '\n7) Stop words removal\n\nStop words are words that are considered unimportant to the meaning of a text.\nThese words may seem important to us, humans, but to machine these words may be\nconsidered nuisance to the processing steps.\n\nIt’s also important to keep in mind that stop words are largely language-dependent.\nIn English, you have stop words such as for, to, and, or, in, out, etc.\n\nHere I first defined a list of stop words in English.\nThen, I match each token with each stop word.\n\nIf a token isn’t found in the list of stop words, the token gets saved,\notherwise it’s not saved. In the end, you join all the words into one text again.\n\n\nstopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]\n \ntemp = [w for w in temp if not w in stopwords]\ntemp = " ".join(word for word in temp)\n'

# %%
'''
Text Preprocessing: From Start to Finish

I hope you understand the steps I have explained above.
Now we can combine all those lines of code into one function that we can
call and pass an argument to.

The function then returns a clean text that is ready for you to work with.

Keep in mind that the order of steps here are not absolute.
You can arrange them around depending on your text and your needs.
The code below is what I found to be the most effective on the data I
usually work with, but in case you find another pattern of data,
you can always work them out differently.
'''
import numpy as np
import re

stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
tweets = ["Get ready for #NatGeoEarthDay! Join us on 4/21 for an evening of music and celebration, exploration and inspiration https://on.natgeo.com/3t0wzQy.",
"Coral in the shallows of Aitutaki Lagoon, Cook Islands, Polynesia https://on.natgeo.com/3gkgq4Z",
"Don't miss our @reddit AMA with author and climber Mark Synnott who will be answering your questions about his historic journey to the North Face of Everest TODAY at 12:00pm ET! Start submitting your questions here: https://on.natgeo.com/3ddSkHk @DuttonBooks"]
 
results = [clean_tweet(tw) for tw in tweets]
results
# Out:
# C:\Users\Cheong Kenn Ee\AppData\Local\Temp\ipykernel_8044\1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['get ready join us 4 21 evening music celebration exploration inspiration',
#  'coral shallows aitutaki lagoon cook islands polynesia',
#  'dont miss our ama with author climber mark synnott who will be answering your questions about his historic journey north face everest today at 12 00pm et start submitting your questions here']

# %%
# Let's go and apply this to our own tweets
my_results = [clean_tweet(tw) for tw in tweet_text_list]
my_results
# Out:
# C:\Users\Cheong Kenn Ee\AppData\Local\Temp\ipykernel_8044\1029021058.py:22: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# ['rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt 2022',
#  'rt february 4 positive',
#  'rt february 4 positive',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  '2022',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt february 4 positive',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'use indomethacin covid 19 patients experience two medical centres',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'rt estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos',
#  'estudos apontam que gestantes vacinadas com coronavac protegem diretamente seus rec m nascidos pela transmiss o de anticorpos neutralizantes leia mat ria em link para o estudo em',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'february 4 positive 68916 4 757 035 nice 12 00 am 28 81 259 3 21 313',
#  'rt research highlights pulmonary infection by sars cov 2 induces senescence accompanied by inflammatory phenotype',
#  'research highlights pulmonary infection by sars cov 2 induces senescence accompanied by inflammatory phenotype severe covid 19 possible implications viral mutagenesis',
#  'is out today how many were added during 19 s worst spikes previous 199k forecast 238k trade nfp',
#  '',
#  'rt february 3 positive',
#  'not entirely fair also don t forget monthly fines unvaxxed aged',
#  'but healthy people get sick die covid too its not just being fat old that makes covid lethal its also pretty bad health wise get covid better get vaxxed try any avoid getting sick',
#  '',
#  'rt remote work has accelerated during covid 19 new amp report benefits amp concerns as well as roles t',
#  'hey genius how is move state with power grid issues build your electric cars going i bet almost as well as your covid predictions',
#  '',
#  'ministry health kuwait reports 5 990 people tested positive coronavirus covid 19 two deaths past 24 hours',
#  'covered some these our sleep health society textbooks but agree need more sleep cancer concussion mental health covid long covid etc',
#  '',
#  'report rapid assessment survey response labour dispute resolution mechanisms covid 19 pandemic via',
#  '',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'rt february 3 positive',
#  'february 3 positive 82871 4 688 119 nice 12 00 am 14 80 968 7 21 310',
#  'rt 65 covid scandals',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'rt chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public',
#  'chinese government has made enormous efforts prevent olympic participants spreading covid 19 chinese public while making only half hearted efforts prevent participants spreading it each other',
#  'saudi ministry health announced registration 3 852 new infections with coronavirus covid 19 during past 24 hours bringing total number infections recorded country 699 069 four deaths were recorded']

# %%
# importing all necessary modules

# Note that wordcloud package also provides a stop word list
# We won't be using it here - but please do explore!!!
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in results:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
